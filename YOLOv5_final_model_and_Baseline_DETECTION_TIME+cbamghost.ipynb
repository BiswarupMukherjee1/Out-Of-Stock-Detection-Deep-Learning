# %% [markdown]
# YOLOv5 cg

# %%
# !python train.py --img 720 --epochs 100 --data '/content/drive/MyDrive/InfilectDataNewDataset/dataset_t.yaml' --weights yolov5s.pt --cfg yolov5s.yaml
# Out:
# 2023-04-04 11:18:18.865401: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 11:18:19.824211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# ### **Proposed YOLOv5 model Detection Time**

# %%
# !python detect.py --weights '/content/drive/MyDrive/Model_Weights/Ghost Yolov5/best.pt' --source /content/drive/MyDrive/InfilectDataNewDataset/images/val --img 720
# Out:
# detect: weights=['/content/drive/MyDrive/Model_Weights/Ghost Yolov5/best.pt'], source=/content/drive/MyDrive/InfilectDataNewDataset/images/val, data=data/coco128.yaml, imgsz=[720, 720], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 246 layers, 5078974 parameters, 0 gradients, 10.5 GFLOPs
# WARNING ⚠️ --img-size [720, 720] must be multiple of max stride 32, updating to [736, 736]
# image 1/600 /content/drive/MyDrive/InfilectDataNewDataset/images/val/db2711_jpg.rf.01475886dddc758914d3082018e2c505.jpg: 736x736 9 emptys, 605.2ms
# ...

# %% [markdown]
# ### **BaseLine YOLOv5 Detection Time**

# %%
# !python detect.py --weights '/content/drive/MyDrive/Model_Weights/BaseLineYolo/best_baseline_yolo.pt' --source /content/drive/MyDrive/InfilectDataNewDataset/images/val/ --img 720
# Out:
# detect: weights=['/content/drive/MyDrive/Model_Weights/BaseLineYolo/best_baseline_yolo.pt'], source=/content/drive/MyDrive/InfilectDataNewDataset/images/val/, data=data/coco128.yaml, imgsz=[720, 720], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-133-gcca5e21 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ --img-size [720, 720] must be multiple of max stride 32, updating to [736, 736]
# image 1/600 /content/drive/MyDrive/InfilectDataNewDataset/images/val/db2711_jpg.rf.01475886dddc758914d3082018e2c505.jpg: 736x736 9 emptys, 777.9ms
# ...
